# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b252dd8c-1834-481a-ad6c-569643236c65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b252dd8c-1834-481a-ad6c-569643236c65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
data = pd.read_csv(io.BytesIO(uploaded['tested.csv']))

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
len(data)
# Out:
# 418

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#countplot of survived vs not survived

# %%
sns.countplot(x="Survived",data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",data=data,hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
data.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %%
data["Age"].isna().sum()/len(data["Age"])*100
# Out:
# 20.574162679425836

# %%
data["Cabin"].isna().sum()/len(data["Cabin"])*100
# Out:
# 78.22966507177034

# %%
sns.displot(x="Age",data=data)

# %%
data.Age=data.Age.fillna(data.Age.mean())
data.Age
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
#          ...
# 413    30.27259
# 414    39.00000
# 415    38.50000
# 416    30.27259
# 417    30.27259
# Name: Age, Length: 418, dtype: float64

# %%
data['Age'].isna().sum()
# Out:
# 0

# %%
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %%
data.drop("Cabin",axis=1,inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
gender=pd.get_dummies(data["Sex"],drop_first=True)

# %%
data["gender"]=gender

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked  gender
# 0   330911   7.8292        Q       1
# 1   363272   7.0000        S       0
# 2   240276   9.6875        Q       1
# 3   315154   8.6625        S       1
# 4  3101298  12.2875        S       0

# %%
data.drop(['Sex','Name','Ticket'],axis=1,inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare Embarked  \
# 0            892         0       3  34.50000      0      0    7.8292        Q
# 1            893         1       3  47.00000      1      0    7.0000        S
# 2            894         0       2  62.00000      0      0    9.6875        Q
# 3            895         0       3  27.00000      0      0    8.6625        S
# 4            896         1       3  22.00000      1      1   12.2875        S
# ..           ...       ...     ...       ...    ...    ...       ...      ...
# 413         1305         0       3  30.27259      0      0    8.0500        S
# 414         1306         1       1  39.00000      0      0  108.9000        C
# 415         1307         0       3  38.50000      0      0    7.2500        S
# 416         1308         0       3  30.27259      0      0    8.0500        S
# 417         1309         0       3  30.27259      1      1   22.3583        C
#
#      gender
# 0         1
# ...

# %%
data.drop(['Embarked'],axis=1,inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare  gender
# 0            892         0       3  34.50000      0      0    7.8292       1
# 1            893         1       3  47.00000      1      0    7.0000       0
# 2            894         0       2  62.00000      0      0    9.6875       1
# 3            895         0       3  27.00000      0      0    8.6625       1
# 4            896         1       3  22.00000      1      1   12.2875       0
# ..           ...       ...     ...       ...    ...    ...       ...     ...
# 413         1305         0       3  30.27259      0      0    8.0500       1
# 414         1306         1       1  39.00000      0      0  108.9000       0
# 415         1307         0       3  38.50000      0      0    7.2500       1
# 416         1308         0       3  30.27259      0      0    8.0500       1
# 417         1309         0       3  30.27259      1      1   22.3583       1
#
# [418 rows x 8 columns]

# %%
x=data[["PassengerId",'Pclass','Age',"SibSp",'Parch','Fare','gender']]
y=data['Survived']

# %% [markdown]
# # #Data modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
x_test_scaled_with_feature_names = scaler.transform(x_test)
x_test_scaled_with_feature_names = pd.DataFrame(x_test_scaled_with_feature_names, columns=x_train.columns)

# %%
predictions = lr.predict(x_test_scaled_with_feature_names)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# # #testing

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,predict)
# Out:
# array([[91,  1],
#        [41,  5]])

# %%
pd.DataFrame(confusion_matrix(y_test,predict),columns=['Predicted NO','Predicted Yes'],index=['Actual no ',"Actual no"])
# Out:
#             Predicted NO  Predicted Yes
# Actual no             91              1
# Actual no             41              5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Predicted NO'].plot(kind='hist', bins=20, title='Predicted NO')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Predicted Yes'].plot(kind='hist', bins=20, title='Predicted Yes')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Predicted NO', y='Predicted Yes', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from  sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.99      0.81        92
#            1       0.83      0.11      0.19        46
#
#     accuracy                           0.70       138
#    macro avg       0.76      0.55      0.50       138
# weighted avg       0.74      0.70      0.61       138

# %% [markdown]
# precision: is the ratio of correctly predicted positive  observation to the total predicted positive observations
#
#
# Recall :is the ratio of correctly predicting positive observation to the all observation in actual class F1 score -F1 score is the weighted average of prediction and recall

# %% [markdown]
# # **DATA SET PREDICTED BY:**
#
#
#    SAM MESHACH A
#    sammeshach333@gmail.com
